# %% [markdown]
# # 01 - Member 2 Big Picture
#
# This notebook explains the role of Member 2 in the project. Member 2 owns the Agentic RAG workflow: the part that connects legal retrieval, web references, LLM reasoning, and final JSON output.
#
# You can run this notebook without an OpenRouter API key.

# %% [markdown]
# ## Workflow Map
#
# ```text
# User question
#   -> identify legal issues
#   -> retrieve legal basis from Member 1's tool
#   -> search practical web references
#   -> scrape selected URLs
#   -> synthesize final JSON with the LLM
#   -> Member 3 displays JSON in Streamlit
# ```
#
# The important idea: **legal basis and practical references are separate**. Legal basis comes from Member 1's retrieval system. Web pages are examples only.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %%
important_paths = [
    "src/agent/agent_workflow.py",
    "src/agent/llm_client.py",
    "src/agent/tools/legal_retrieval_tool.py",
    "src/agent/tools/web_search_tool.py",
    "src/agent/tools/web_scraper_tool.py",
    "src/agent/schemas/output_schema.py",
    "src/frontend/app.py",
    "src/retrieval/query_engine_tool.py",
]

for relative_path in important_paths:
    path = PROJECT_ROOT / relative_path
    print(f"{relative_path}: {'exists' if path.exists() else 'missing'}")

# %% [markdown]
# ## Ownership
#
# - `src/agent/`: Member 2's main workspace.
# - `src/retrieval/`: Member 1's retrieval implementation.
# - `src/frontend/`: Member 3's Streamlit UI.
# - `src/evaluation/`: Member 3's evaluation scripts.
#
# Member 2 should not depend on retrieval internals. Use the adapter in `src/agent/tools/legal_retrieval_tool.py`.

# %%
from src.agent.agent_workflow import answer_labor_law_question

answer_labor_law_question

# %% [markdown]
# ## What You Should Understand Now
#
# You should know where Member 2's code lives, how the Agentic RAG workflow is shaped, and why the final output must be structured JSON instead of free-form text.
